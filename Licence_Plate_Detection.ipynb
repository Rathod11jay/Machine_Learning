# %%
# !pip install ultralytics

from ultralytics import YOLO

model = YOLO('/content/best.pt')
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.1/922.1 kB 17.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 53.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !unzip /content/testimg.zip
# Out:
# Archive:  /content/testimg.zip
#    creating: test/
#   inflating: test/1000.jpg
#   inflating: test/1001.jpg
#   inflating: test/1002.jpg
#   inflating: test/1003.jpg
#   inflating: test/1004.jpg
#   inflating: test/1005.jpg
#   inflating: test/1006.jpg
#   inflating: test/1007.jpg
#   inflating: test/1008.jpg
#   inflating: test/1009.jpg
#   inflating: test/1010.jpg
#   inflating: test/1011.jpg
#   inflating: test/1012.jpg
#   inflating: test/1013.jpg
#   inflating: test/1014.jpg
#   inflating: test/1015.jpg
#   inflating: test/1016.jpg
#   inflating: test/1017.jpg
#   inflating: test/1018.jpg
#   inflating: test/1019.jpg
#   inflating: test/1020.jpg
#   inflating: test/1021.jpg
#   inflating: test/1022.jpg
#   inflating: test/1023.jpg
#   inflating: test/1024.jpg
#   inflating: test/1025.jpg
#   inflating: test/1026.jpg
#   inflating: test/1027.jpg
#   inflating: test/1028.jpg
#   inflating: test/1029.jpg
#   inflating: test/1030.jpg
#   inflating: test/1031.jpg
# ...

# %%
# Run prediction on all test images and save results
results = model.predict(source='/content/test', imgsz=640, conf=0.3, save=True)

print('Predicted images saved')
# Out:
# image 1/210 /content/test/1000.jpg: 448x640 1 license plate, 421.3ms
# image 2/210 /content/test/1001.jpg: 640x384 1 license plate, 174.9ms
# image 3/210 /content/test/1002.jpg: 640x480 1 license plate, 212.9ms
# image 4/210 /content/test/1003.jpg: 384x640 1 license plate, 183.9ms
# image 5/210 /content/test/1004.jpg: 640x384 1 license plate, 154.3ms
# image 6/210 /content/test/1005.jpg: 640x384 1 license plate, 163.1ms
# image 7/210 /content/test/1006.jpg: 640x480 1 license plate, 185.0ms
# image 8/210 /content/test/1007.jpg: 640x384 1 license plate, 152.4ms
# image 9/210 /content/test/1008.jpg: 384x640 1 license plate, 159.8ms
# image 10/210 /content/test/1009.jpg: 384x640 1 license plate, 154.0ms
# image 11/210 /content/test/1010.jpg: 640x384 1 license plate, 160.6ms
# image 12/210 /content/test/1011.jpg: 640x384 1 license plate, 151.7ms
# image 13/210 /content/test/1012.jpg: 480x640 1 license plate, 195.3ms
# image 14/210 /content/test/1013.jpg: 640x480 1 license plate, 190.3ms
# ...

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# !zip -r runs.zip /content/runs/detect/predict
# Out:
#   adding: content/runs/detect/predict/ (stored 0%)
#   adding: content/runs/detect/predict/1016.jpg (deflated 0%)
#   adding: content/runs/detect/predict/1076.jpg (deflated 1%)
#   adding: content/runs/detect/predict/1002.jpg (deflated 1%)
#   adding: content/runs/detect/predict/1044.jpg (deflated 1%)
#   adding: content/runs/detect/predict/1099.jpg (deflated 1%)
#   adding: content/runs/detect/predict/905.jpg (deflated 1%)
#   adding: content/runs/detect/predict/942.jpg (deflated 1%)
#   adding: content/runs/detect/predict/1032.jpg (deflated 1%)
#   adding: content/runs/detect/predict/1038.jpg (deflated 1%)
#   adding: content/runs/detect/predict/1021.jpg (deflated 1%)
#   adding: content/runs/detect/predict/926.jpg (deflated 1%)
#   adding: content/runs/detect/predict/953.jpg (deflated 1%)
#   adding: content/runs/detect/predict/1095.jpg (deflated 1%)
#   adding: content/runs/detect/predict/1022.jpg (deflated 1%)
#   adding: content/runs/detect/predict/1090.jpg (deflated 1%)
# ...
